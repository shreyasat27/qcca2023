# %% [markdown]
# # Quantum Circuits and Visualisations

# %%
# !pip install qiskit[visualization]
# !pip install qiskit-aer
# !pip install qiskit-ibmq-provider
# !pip install qiskit_ibm_provider
from qiskit import *
from qiskit import QuantumCircuit, transpile
from qiskit_ibm_provider import IBMProvider

from qiskit_ibm_provider import IBMProvider
from qiskit.visualization import plot_histogram
from qiskit.visualization import plot_distribution
# Out:
# Collecting qiskit[visualization]
#   Downloading qiskit-0.44.3-py3-none-any.whl (8.2 kB)
# Collecting qiskit-terra==0.25.3 (from qiskit[visualization])
#   Downloading qiskit_terra-0.25.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 10.5 MB/s eta 0:00:00
# Collecting rustworkx>=0.13.0 (from qiskit-terra==0.25.3->qiskit[visualization])
#   Downloading rustworkx-0.13.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 24.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.3->qiskit[visualization]) (1.23.5)
# Collecting ply>=3.10 (from qiskit-terra==0.25.3->qiskit[visualization])
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.3->qiskit[visualization]) (5.9.5)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.3->qiskit[visualization]) (1.11.3)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.3->qiskit[visualization]) (1.12)
# Collecting dill>=0.3 (from qiskit-terra==0.25.3->qiskit[visualization])
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 13.0 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.3->qiskit[visualization]) (2.8.2)
# Collecting stevedore>=3.0.0 (from qiskit-terra==0.25.3->qiskit[visualization])
#   Downloading stevedore-5.1.0-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 4.0 MB/s eta 0:00:00
# Collecting symengine<0.10,>=0.9 (from qiskit-terra==0.25.3->qiskit[visualization])
#   Downloading symengine-0.9.2-cp310-cp310-manylinux2010_x86_64.whl (37.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.5/37.5 MB 39.1 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.3->qiskit[visualization]) (4.5.0)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.3->qiskit[visualization]) (3.7.1)
# Requirement already satisfied: ipywidgets>=7.3.0 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.3->qiskit[visualization]) (7.7.1)
# Requirement already satisfied: pydot in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.3->qiskit[visualization]) (1.4.2)
# Requirement already satisfied: pillow>=4.2.1 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.3->qiskit[visualization]) (9.4.0)
# Collecting pylatexenc>=1.4 (from qiskit-terra==0.25.3->qiskit[visualization])
#   Downloading pylatexenc-2.10.tar.gz (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 16.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: seaborn>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.3->qiskit[visualization]) (0.12.2)
# Requirement already satisfied: pygments>=2.4 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.3->qiskit[visualization]) (2.16.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (5.5.6)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->qiskit-terra==0.25.3->qiskit[visualization]) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->qiskit-terra==0.25.3->qiskit[visualization]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->qiskit-terra==0.25.3->qiskit[visualization]) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->qiskit-terra==0.25.3->qiskit[visualization]) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->qiskit-terra==0.25.3->qiskit[visualization]) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3->qiskit-terra==0.25.3->qiskit[visualization]) (3.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.0->qiskit-terra==0.25.3->qiskit[visualization]) (1.16.0)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.10/dist-packages (from seaborn>=0.9.0->qiskit-terra==0.25.3->qiskit[visualization]) (1.5.3)
# Collecting pbr!=2.1.0,>=2.0.0 (from stevedore>=3.0.0->qiskit-terra==0.25.3->qiskit[visualization])
#   Downloading pbr-5.11.1-py2.py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.7/112.7 kB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy>=1.3->qiskit-terra==0.25.3->qiskit[visualization]) (1.3.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (6.3.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (67.7.2)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization])
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 71.4 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (3.0.39)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=4.0.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (4.8.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->seaborn>=0.9.0->qiskit-terra==0.25.3->qiskit[visualization]) (2023.3.post1)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (6.5.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (0.8.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (3.1.2)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (23.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (5.4.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (5.9.2)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (6.5.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (1.5.8)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (0.17.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (1.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (0.2.8)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (3.11.0)
# Requirement already satisfied: jupyter-server>=1.8 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (0.2.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (4.11.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (0.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (2.1.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (2.18.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (4.19.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (21.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (0.10.6)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (3.7.1)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (1.6.4)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (0.5.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (1.1.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.3.0->qiskit-terra==0.25.3->qiskit[visualization]) (2.21)
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (setup.py) ... done
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136818 sha256=cb19db875a34d3373dd36f224ad3309aed495829d5dac4a213718b24f669f061
#   Stored in directory: /root/.cache/pip/wheels/d3/31/8b/e09b0386afd80cfc556c00408c9aeea5c35c4d484a9c762fd5
# Successfully built pylatexenc
# Installing collected packages: pylatexenc, ply, symengine, rustworkx, pbr, jedi, dill, stevedore, qiskit-terra, qiskit
# Successfully installed dill-0.3.7 jedi-0.19.1 pbr-5.11.1 ply-3.11 pylatexenc-2.10 qiskit-0.44.3 qiskit-terra-0.25.3 rustworkx-0.13.2 stevedore-5.1.0 symengine-0.9.2
# Collecting qiskit-aer
#   Downloading qiskit_aer-0.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 51.9 MB/s eta 0:00:00
# Requirement already satisfied: qiskit>=0.44.0 in /usr/local/lib/python3.10/dist-packages (from qiskit-aer) (0.44.3)
# Requirement already satisfied: numpy>=1.16.3 in /usr/local/lib/python3.10/dist-packages (from qiskit-aer) (1.23.5)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from qiskit-aer) (1.11.3)
# Requirement already satisfied: qiskit-terra==0.25.3 in /usr/local/lib/python3.10/dist-packages (from qiskit>=0.44.0->qiskit-aer) (0.25.3)
# Requirement already satisfied: rustworkx>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.3->qiskit>=0.44.0->qiskit-aer) (0.13.2)
# Requirement already satisfied: ply>=3.10 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.3->qiskit>=0.44.0->qiskit-aer) (3.11)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.3->qiskit>=0.44.0->qiskit-aer) (5.9.5)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.3->qiskit>=0.44.0->qiskit-aer) (1.12)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.3->qiskit>=0.44.0->qiskit-aer) (0.3.7)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.3->qiskit>=0.44.0->qiskit-aer) (2.8.2)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.3->qiskit>=0.44.0->qiskit-aer) (5.1.0)
# Requirement already satisfied: symengine<0.10,>=0.9 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.3->qiskit>=0.44.0->qiskit-aer) (0.9.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.3->qiskit>=0.44.0->qiskit-aer) (4.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.0->qiskit-terra==0.25.3->qiskit>=0.44.0->qiskit-aer) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from stevedore>=3.0.0->qiskit-terra==0.25.3->qiskit>=0.44.0->qiskit-aer) (5.11.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy>=1.3->qiskit-terra==0.25.3->qiskit>=0.44.0->qiskit-aer) (1.3.0)
# Installing collected packages: qiskit-aer
# Successfully installed qiskit-aer-0.13.0
# Collecting qiskit-ibmq-provider
#   Downloading qiskit_ibmq_provider-0.20.2-py3-none-any.whl (241 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.5/241.5 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: qiskit-terra>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from qiskit-ibmq-provider) (0.25.3)
# Requirement already satisfied: requests>=2.19 in /usr/local/lib/python3.10/dist-packages (from qiskit-ibmq-provider) (2.31.0)
# Collecting requests-ntlm<=1.1.0 (from qiskit-ibmq-provider)
#   Downloading requests_ntlm-1.1.0-py2.py3-none-any.whl (5.7 kB)
# Requirement already satisfied: numpy<1.24 in /usr/local/lib/python3.10/dist-packages (from qiskit-ibmq-provider) (1.23.5)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from qiskit-ibmq-provider) (2.0.7)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from qiskit-ibmq-provider) (2.8.2)
# Requirement already satisfied: websocket-client>=1.5.1 in /usr/local/lib/python3.10/dist-packages (from qiskit-ibmq-provider) (1.6.4)
# Collecting websockets>=10.0 (from qiskit-ibmq-provider)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 13.5 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.0->qiskit-ibmq-provider) (1.16.0)
# Requirement already satisfied: rustworkx>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (0.13.2)
# Requirement already satisfied: ply>=3.10 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (3.11)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (5.9.5)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (1.11.3)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (1.12)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (0.3.7)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (5.1.0)
# Requirement already satisfied: symengine<0.10,>=0.9 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (0.9.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from qiskit-terra>=0.18.0->qiskit-ibmq-provider) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19->qiskit-ibmq-provider) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19->qiskit-ibmq-provider) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19->qiskit-ibmq-provider) (2023.7.22)
# Collecting ntlm-auth>=1.0.2 (from requests-ntlm<=1.1.0->qiskit-ibmq-provider)
#   Downloading ntlm_auth-1.5.0-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: cryptography>=1.3 in /usr/local/lib/python3.10/dist-packages (from requests-ntlm<=1.1.0->qiskit-ibmq-provider) (41.0.5)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=1.3->requests-ntlm<=1.1.0->qiskit-ibmq-provider) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from stevedore>=3.0.0->qiskit-terra>=0.18.0->qiskit-ibmq-provider) (5.11.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy>=1.3->qiskit-terra>=0.18.0->qiskit-ibmq-provider) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm<=1.1.0->qiskit-ibmq-provider) (2.21)
# Installing collected packages: websockets, ntlm-auth, requests-ntlm, qiskit-ibmq-provider
# Successfully installed ntlm-auth-1.5.0 qiskit-ibmq-provider-0.20.2 requests-ntlm-1.1.0 websockets-12.0
# Collecting qiskit_ibm_provider
#   Downloading qiskit_ibm_provider-0.7.2-py3-none-any.whl (243 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.3/243.3 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: qiskit>=0.44.1 in /usr/local/lib/python3.10/dist-packages (from qiskit_ibm_provider) (0.44.3)
# Requirement already satisfied: requests>=2.19 in /usr/local/lib/python3.10/dist-packages (from qiskit_ibm_provider) (2.31.0)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from qiskit_ibm_provider) (1.1.0)
# Requirement already satisfied: numpy>=1.13 in /usr/local/lib/python3.10/dist-packages (from qiskit_ibm_provider) (1.23.5)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from qiskit_ibm_provider) (2.0.7)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from qiskit_ibm_provider) (2.8.2)
# Requirement already satisfied: websocket-client>=1.5.1 in /usr/local/lib/python3.10/dist-packages (from qiskit_ibm_provider) (1.6.4)
# Requirement already satisfied: websockets>=10.0 in /usr/local/lib/python3.10/dist-packages (from qiskit_ibm_provider) (12.0)
# Requirement already satisfied: typing-extensions>=4.3 in /usr/local/lib/python3.10/dist-packages (from qiskit_ibm_provider) (4.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.0->qiskit_ibm_provider) (1.16.0)
# Requirement already satisfied: qiskit-terra==0.25.3 in /usr/local/lib/python3.10/dist-packages (from qiskit>=0.44.1->qiskit_ibm_provider) (0.25.3)
# Requirement already satisfied: rustworkx>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.3->qiskit>=0.44.1->qiskit_ibm_provider) (0.13.2)
# Requirement already satisfied: ply>=3.10 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.3->qiskit>=0.44.1->qiskit_ibm_provider) (3.11)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.3->qiskit>=0.44.1->qiskit_ibm_provider) (5.9.5)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.3->qiskit>=0.44.1->qiskit_ibm_provider) (1.11.3)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.3->qiskit>=0.44.1->qiskit_ibm_provider) (1.12)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.3->qiskit>=0.44.1->qiskit_ibm_provider) (0.3.7)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.3->qiskit>=0.44.1->qiskit_ibm_provider) (5.1.0)
# Requirement already satisfied: symengine<0.10,>=0.9 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.3->qiskit>=0.44.1->qiskit_ibm_provider) (0.9.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19->qiskit_ibm_provider) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19->qiskit_ibm_provider) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19->qiskit_ibm_provider) (2023.7.22)
# Requirement already satisfied: ntlm-auth>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from requests-ntlm>=1.1.0->qiskit_ibm_provider) (1.5.0)
# Requirement already satisfied: cryptography>=1.3 in /usr/local/lib/python3.10/dist-packages (from requests-ntlm>=1.1.0->qiskit_ibm_provider) (41.0.5)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_provider) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit_ibm_provider) (2.21)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from stevedore>=3.0.0->qiskit-terra==0.25.3->qiskit>=0.44.1->qiskit_ibm_provider) (5.11.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy>=1.3->qiskit-terra==0.25.3->qiskit>=0.44.1->qiskit_ibm_provider) (1.3.0)
# Installing collected packages: qiskit_ibm_provider
# Successfully installed qiskit_ibm_provider-0.7.2

# %%
from qiskit import *
# %matplotlib inline

# %% [markdown]
# ### Creating a circuit
# Let's work on creating our first circuit!

# %%
#create a quantum register with 2 qubits
qr = QuantumRegister(2)

#create a classical register with 2 bits
cr = ClassicalRegister(2)

#create a quantum circuit with both registers
qc = QuantumCircuit(qr, cr)

# %% [markdown]
# Let's visualise our circuit like we did on the IBM Circuit Composer

# %%
#draw circuit
qc.draw(output = 'mpl')

# %% [markdown]
# Hmm... This circuit isn't very interesting. Let's implement a NOT gate on our second qubit $q_1$

# %%
#add an X gate to qubit 1
qc.x(1)
qc.draw('mpl')

# %% [markdown]
# Now, let's move onto more quantum gates. Implement a H gate on our first qubit $q_0$

# %%
#add a H gate to qubit 0
qc.h(0)
qc.draw('mpl')

# %% [markdown]
# Now, add a two-qubit gate: a CX gate on $q_0$ and $q_1$

# %%
#add a CX gate with control as qubit 0 and target as qubit 1
qc.cx(0,1)
qc.draw('mpl')

# %% [markdown]
# Now, we have a circuit that creates entanglement! We next measure out qubits into our classical register

# %%
#measure quantum circuit
qc.measure(qr,cr)
qc.draw('mpl')

# %% [markdown]
# We're done constructing out circuit!
#
#
#
# ---
#
#
# Before we proceed, we can write out our computation in bra-ket notation to see what it does.
#
#
# > First, we started with an empty circuit: $|0\rangle_0|0\rangle_1$
#
# > Then, we applied X on $q_1$: $|0\rangle_0 (X|0\rangle_1) \\= |0\rangle_0|1\rangle_1$
#
# > Next, we apply H on $q_0$: $(H|0\rangle_0)|1\rangle_1 \\= \frac{1}{\sqrt{2}}(|0\rangle_0 + |1\rangle_0)|1\rangle_1  \\= \frac{1}{\sqrt{2}}|0\rangle_0|1\rangle_1 + \frac{1}{\sqrt{2}}|1\rangle_0|1\rangle_1$
#
# > We apply the CX gate with $q_0$ as control and $q_1$ as target:$\\CX(\frac{1}{\sqrt{2}}|0\rangle_0|1\rangle_1 + \frac{1}{\sqrt{2}}|1\rangle_0|1\rangle_1) \\= \frac{1}{\sqrt{2}}|0\rangle_0|1\rangle_1 + \frac{1}{\sqrt{2}}|1\rangle_0|0\rangle_1$
#
# We have entanglement! If the $q_0$ is measured to be 0, $q_1$ is measured to be 1. If the $q_0$ is measured to be 1, $q_1$ is measured to be 0.
#
# ---

# %%
#Ex 1: create circuit entanglement for 1/sqrt(2) (|00> + |11>)
qc2 = QuantumCircuit(2,2)

qc2.h(0)
qc2.measure_all()
qc2.draw('mpl')

# %% [markdown]
# We now test our circuit on our classical computer (a quantum computing simulator), and then send our code to an actual quantum computer.
#
# First, we select our simulator:

# %%
#select qasm_simulator
simulator = Aer.get_backend('qasm_simulator')

# %% [markdown]
# Next, we execute our circuit on our simulator.
#
# *  ```experiments``` is used to specify the circuit to be run
# *   ```backend``` is used to specify our simulator
# *  ```shots``` is used to denote how many times the circuit should be run

# %%
#execute circuit and store result
result = execute(experiments = qc, backend = simulator, shots = 1024).result()


#get counts from obtained result
counts = result.get_counts()

# %%
#execute circuit and store result
result2 = execute(experiments = qc2, backend = simulator, shots = 1024).result()

#get counts from obtained result
counts2 = result2.get_counts()

# %%
#visualise output obtained
from qiskit.tools.visualization import *
plot_histogram(counts)

# %%
plot_histogram(counts2)

# %% [markdown]
# Why do we run the circuit 1024 times? Let's see our result when we run it only once

# %%
#execute circuit with shots = 1 and store result
result = execute(experiments = qc, backend = simulator, shots = 1).result()

#get counts from obtained result
counts = result.get_counts()

#visualise output obtained
from qiskit.tools.visualization import *
plot_histogram(counts)

# %% [markdown]
# Now that our circuit has been tested on a classical simulator, let's run it on a quantum computer.
#
# Set up your IBMQ account and access your API token for your IBMQ account here: https://quantum-computing.ibm.com/account

# %%
 #Save account credentials.
IBMProvider.save_account(token='106701415c7ca974e86c0c32e6153410cb982ba6a6e3e6369f0d9787535cc973fcf79bb738c3f99160286604f8c4f51fc4d79cbcfbecf13bbfbd915453a948ee', overwrite=True)
provider = IBMProvider()

# %%
#load account
IBMQ.load_account()
# Out:
# ibmqfactory.load_account:WARNING:2023-10-29 06:10:28,545: Credentials are already in use. The existing account in the session will be replaced.
# <AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>

# %% [markdown]
# Let's list the available backends to simulate our quantum circuit

# %%
# Select a different hub/group/project.
provider = IBMProvider()
provider = IBMProvider(instance="ibm-q/open/main")

#list available backends
provider.backends()
# Out:
# [<IBMBackend('simulator_statevector')>,
#  <IBMBackend('ibm_nairobi')>,
#  <IBMBackend('simulator_stabilizer')>,
#  <IBMBackend('ibm_lagos')>,
#  <IBMBackend('ibm_perth')>,
#  <IBMBackend('ibm_brisbane')>,
#  <IBMBackend('ibmq_qasm_simulator')>,
#  <IBMBackend('simulator_extended_stabilizer')>,
#  <IBMBackend('simulator_mps')>]

# %% [markdown]
# We can know more details about our actual quantum computers using ```backend_overview```

# %%
#check overview of available quantum computers
from qiskit.tools.monitor import backend_overview
backend_overview()
# Out:
# ibm_brisbane                 ibm_perth                    ibm_nairobi
# ------------                 ---------                    -----------
# Num. Qubits:  127            Num. Qubits:  7              Num. Qubits:  7
# Pending Jobs: 184            Pending Jobs: 3008           Pending Jobs: 5
# Least busy:   False          Least busy:   False          Least busy:   False
# Operational:  True           Operational:  True           Operational:  True
# Avg. T1:      232.6          Avg. T1:      165.1          Avg. T1:      98.5
# Avg. T2:      145.6          Avg. T2:      133.7          Avg. T2:      62.9
#
#
#
# ibm_lagos
# ---------
# Num. Qubits:  7
# Pending Jobs: 0
# Least busy:   True
# Operational:  True
# Avg. T1:      108.5
# Avg. T2:      66.0

# %% [markdown]
# The least busy is ```'ibm_lagos'``` and it has enough qubits to run our circuit on. Let's select it as our backend

# %%
#select ibm_lagos as the quantum computer
backend = provider.get_backend('ibm_lagos')

#to transpile the circuit
New_qc= transpile(qc, backend)

# %% [markdown]
# Now, it's time to execute it on an actual quantum computer!

# %%
#execute our circuit on the selected quantum backend
job = backend.run(New_qc)

# %% [markdown]
# We can monitor the status of our job

# %%
from qiskit.tools.monitor import job_monitor
job_monitor(job)
# Out:
# Job Status: job has successfully run

# %% [markdown]
# Once the job is done, it's time to plot our results

# %%
result = job.result()
plot_distribution(result.get_counts(New_qc))

# %% [markdown]
# We see how some results are 00 and 11 - this is due to quantum error

# %% [markdown]
# ---
#
# Now, let's see how different gates act on different states. We'll use the bloch sphere to understand our results.
#
# First, we apply the I, X, Y and Z gates on |0>

# %%
qc1 = QuantumCircuit(4)

# perform gate operations on individual qubits
qc.i(0)
qc1.x(1)
qc1.y(2)
qc1.z(3)


# Draw circuit
qc1.draw()
# Out:
#
# q_0: ─────
#      ┌───┐
# q_1: ┤ X ├
#      ├───┤
# q_2: ┤ Y ├
#      ├───┤
# q_3: ┤ Z ├
#      └───┘

# %% [markdown]
# Let's plot our Bloch Spheres to see how they've changed!

# %%
# Plot blochshere
simulator = Aer.get_backend('statevector_simulator')
out1 = execute(qc1,simulator).result().get_statevector()
plot_bloch_multivector(out1)

# %% [markdown]
# ---
#
#
# Now, we initialise all our qubits to |1> and then perform our operations

# %%
qc2 = QuantumCircuit(4)

# initialize qubits to |1>
qc2.x(range(4))

# perform gate operations on individual qubits
qc2.x(1)
qc2.y(2)
qc2.z(3)

# Draw circuit
qc2.draw()
# Out:
#      ┌───┐
# q_0: ┤ X ├─────
#      ├───┤┌───┐
# q_1: ┤ X ├┤ X ├
#      ├───┤├───┤
# q_2: ┤ X ├┤ Y ├
#      ├───┤├───┤
# q_3: ┤ X ├┤ Z ├
#      └───┘└───┘

# %%
# Plot blochshere
out2 = execute(qc2,simulator).result().get_statevector()
plot_bloch_multivector(out2)

# %% [markdown]
# ---
#
#
# Finally, let's try with a different basis state: |+>

# %%
qc3 = QuantumCircuit(4)

# initialize qubits to |1>
qc3.h(range(4))

# perform gate operations on individual qubits
qc3.x(1)
qc3.y(2)
qc3.z(3)

# Draw circuit
qc3.draw()
# Out:
#      ┌───┐
# q_0: ┤ H ├─────
#      ├───┤┌───┐
# q_1: ┤ H ├┤ X ├
#      ├───┤├───┤
# q_2: ┤ H ├┤ Y ├
#      ├───┤├───┤
# q_3: ┤ H ├┤ Z ├
#      └───┘└───┘

# %%
# Plot blochshere
out3 = execute(qc3,simulator).result().get_statevector()
plot_bloch_multivector(out3)

# %% [markdown]
# ---
#
# Let's finally explore how you can use ```unitary_simulator``` to view the effective matrix after applying your operations

# %%
#Constructing HZH gate
from qiskit.visualization import array_to_latex

qc = QuantumCircuit(1)
qc.h(0)
qc.z(0)
qc.h(0)

sim = Aer.get_backend('unitary_simulator')
array_to_latex(sim.run(qc).result().get_unitary())
# Out:
# $$
#
# \begin{bmatrix}
# 0 & 1  \\
#  1 & 0  \\
#  \end{bmatrix}
# $$

# %%
outHZH = execute(qc,simulator).result().get_statevector()
plot_bloch_multivector(outHZH)

# %%
array_to_latex(outHZH)
# Out:
# $$
#
# \begin{bmatrix}
# 0 & 1  \\
#  \end{bmatrix}
# $$
